# %% [markdown]
# <a href="https://colab.research.google.com/github/aadiharan99/DL_Labwork/blob/master/J014_Lab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import numpy as np
import requests
import cv2
import PIL.Image
import urllib

ind_ele_page = requests.get("http://image-net.org/api/text/imagenet.synset.geturls?wnid=n02504013")

# %%
afr_ele_page = requests.get("http://image-net.org/api/text/imagenet.synset.geturls?wnid=n02504458")
nor_ele_page = requests.get("http://image-net.org/api/text/imagenet.synset.geturls?wnid=n02505063")

# %%
ind_soup = BeautifulSoup(ind_ele_page.content, 'html.parser')
afr_soup = BeautifulSoup(afr_ele_page.content, 'html.parser')
nor_soup = BeautifulSoup(nor_ele_page.content, 'html.parser')

# %%
str_soup_ind=str(ind_soup)
split_urls_ind=str_soup_ind.split('\r\n')
str_soup_afr=str(afr_soup)
split_urls_afr=str_soup_afr.split('\r\n')
str_soup_nor=str(nor_soup)
split_urls_nor=str_soup_nor.split('\r\n')

# %%
# !mkdir /content/train #create the Train folder
# !mkdir /content/train/indele #create the ships folder
# !mkdir /content/train/afrele
# !mkdir /content/train/norele #create the bikes folder
# !mkdir /content/validation
# !mkdir /content/validation/indele #create the ships folder
# !mkdir /content/validation/afrele
# !mkdir /content/validation/norele

# %%
# !mkdir /content/test/ 
# !mkdir /content/test/test

# %%
img_rows, img_cols = 32, 32 #number of rows and columns to convert the images to
input_shape = (img_rows, img_cols, 3)

# %%
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urllib.request.urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
n_of_training_images=150#the number of training images to use
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_ind[progress] == None:
      try:
        I = url_to_image(split_urls_ind[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/indele/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140

# %%
n_of_training_images=150#the number of training images to use
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_afr[progress] == None:
      try:
        I = url_to_image(split_urls_afr[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/afrele/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140

# %%
n_of_training_images=150#the number of training images to use
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_nor[progress] == None:
      try:
        I = url_to_image(split_urls_nor[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/norele/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140

# %%
for progress in range(50):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_ind[progress] == None:
      try:
        I = url_to_image(split_urls_ind[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/indele/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40
# 0

# %%
for progress in range(50):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_afr[progress] == None:
      try:
        I = url_to_image(split_urls_afr[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/afrele/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40

# %%
for progress in range(50):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_nor[progress] == None:
      try:
        I = url_to_image(split_urls_nor[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/norele/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40

# %%
for progress in range(50):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_ind[progress] == None:
      try:
        I = url_to_image(split_urls_ind[n_of_training_images+progress+50])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/test/test/indele_'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40

# %%
for progress in range(50):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_afr[progress] == None:
      try:
        I = url_to_image(split_urls_afr[n_of_training_images+progress+50])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/test/test/afrele_'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40

# %%
for progress in range(50):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not split_urls_nor[progress] == None:
      try:
        I = url_to_image(split_urls_nor[n_of_training_images+progress+50])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/test/test/norele_'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)

      except:
        None
# Out:
# 0
# 20
# 40

# %%
import os
import pandas as pd

original_test = '/content/test/test'
 
filenames = os.listdir(original_test)
categories = []
for filename in filenames:
    category = filename.split('_')[0]
    if category == 'indele':
        categories.append('indele')
    elif category== 'afrele':
        categories.append('afrele')
    elif category== 'norele':
        categories.append('norele')

data = pd.DataFrame({'filename':filenames,'label':categories})

data.to_csv("original.csv",index=False)

# %%
#using fastAI and ResNet50
from fastai.vision import *
from fastai.metrics import accuracy

# %%
train_path='/content/train'

# %%
#reading the original csv
orig_csv=pd.read_csv('/content/original.csv')

# %%
orig_csv
# Out:
#          filename   label
# 0   indele_47.jpg  indele
# 1   indele_14.jpg  indele
# 2   afrele_42.jpg  afrele
# 3    norele_9.jpg  norele
# 4   afrele_13.jpg  afrele
# ..            ...     ...
# 63   afrele_1.jpg  afrele
# 64  norele_16.jpg  norele
# 65   indele_1.jpg  indele
# 66  afrele_47.jpg  afrele
# 67  indele_43.jpg  indele
#
# [68 rows x 2 columns]

# %%
import os
eles = os.listdir("/content/train")
print("No. of labels: {}".format(len(eles)))
print("-----------------")

for label in eles:
    print("{}, {} files".format(label, len(os.listdir("/content/train/"+label))))
# Out:
# No. of labels: 3
# -----------------
# indele, 75 files
# norele, 78 files
# afrele, 110 files

# %%
path = '/content/train'

# %%
size=224
batch_size=64

# %%
data = ImageDataBunch.from_folder(path, ds_tfms=get_transforms(do_flip=True, flip_vert=True),
                                  valid_pct=0.2, size=size, bs=batch_size)

# %%
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (211 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# indele,indele,indele,indele,indele
# Path: /content/train;
#
# Valid: LabelList (52 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# afrele,afrele,indele,norele,norele
# Path: /content/train;
#
# Test: None

# %%
#viewing images in the dataset
data.show_batch(rows=3, figsize=(7,6))

# %%
#creating resNet50 model
learner = create_cnn(data, models.resnet50, metrics=[accuracy], callback_fns=ShowGraph)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(IntProgress(value=0, max=102502400), HTML(value='')))

# %%
#summary
learner.summary()
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 112, 112]       9,408      False
# ______________________________________________________________________
# BatchNorm2d          [64, 112, 112]       128        True
# ______________________________________________________________________
# ReLU                 [64, 112, 112]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 56, 56]         0          False
# ______________________________________________________________________
# Conv2d               [64, 56, 56]         4,096      False
# ______________________________________________________________________
# BatchNorm2d          [64, 56, 56]         128        True
# ______________________________________________________________________
# Conv2d               [64, 56, 56]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 56, 56]         128        True
# ______________________________________________________________________
# Conv2d               [256, 56, 56]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 56, 56]        512        True
# ______________________________________________________________________
# ReLU                 [256, 56, 56]        0          False
# ______________________________________________________________________
# Conv2d               [256, 56, 56]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 56, 56]        512        True
# ______________________________________________________________________
# Conv2d               [64, 56, 56]         16,384     False
# ______________________________________________________________________
# BatchNorm2d          [64, 56, 56]         128        True
# ______________________________________________________________________
# Conv2d               [64, 56, 56]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 56, 56]         128        True
# ______________________________________________________________________
# Conv2d               [256, 56, 56]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 56, 56]        512        True
# ______________________________________________________________________
# ReLU                 [256, 56, 56]        0          False
# ______________________________________________________________________
# Conv2d               [64, 56, 56]         16,384     False
# ______________________________________________________________________
# BatchNorm2d          [64, 56, 56]         128        True
# ______________________________________________________________________
# Conv2d               [64, 56, 56]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 56, 56]         128        True
# ______________________________________________________________________
# Conv2d               [256, 56, 56]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 56, 56]        512        True
# ______________________________________________________________________
# ReLU                 [256, 56, 56]        0          False
# ______________________________________________________________________
# Conv2d               [128, 56, 56]        32,768     False
# ______________________________________________________________________
# BatchNorm2d          [128, 56, 56]        256        True
# ______________________________________________________________________
# Conv2d               [128, 28, 28]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 28, 28]        256        True
# ______________________________________________________________________
# Conv2d               [512, 28, 28]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 28, 28]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 28, 28]        0          False
# ______________________________________________________________________
# Conv2d               [512, 28, 28]        131,072    False
# ______________________________________________________________________
# BatchNorm2d          [512, 28, 28]        1,024      True
# ______________________________________________________________________
# Conv2d               [128, 28, 28]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 28, 28]        256        True
# ______________________________________________________________________
# Conv2d               [128, 28, 28]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 28, 28]        256        True
# ______________________________________________________________________
# Conv2d               [512, 28, 28]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 28, 28]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 28, 28]        0          False
# ______________________________________________________________________
# Conv2d               [128, 28, 28]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 28, 28]        256        True
# ______________________________________________________________________
# Conv2d               [128, 28, 28]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 28, 28]        256        True
# ______________________________________________________________________
# Conv2d               [512, 28, 28]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 28, 28]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 28, 28]        0          False
# ______________________________________________________________________
# Conv2d               [128, 28, 28]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 28, 28]        256        True
# ______________________________________________________________________
# Conv2d               [128, 28, 28]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 28, 28]        256        True
# ______________________________________________________________________
# Conv2d               [512, 28, 28]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 28, 28]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 28, 28]        0          False
# ______________________________________________________________________
# Conv2d               [256, 28, 28]        131,072    False
# ______________________________________________________________________
# BatchNorm2d          [256, 28, 28]        512        True
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 14, 14]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 14, 14]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 14, 14]       0          False
# ______________________________________________________________________
# Conv2d               [1024, 14, 14]       524,288    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 14, 14]       2,048      True
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 14, 14]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 14, 14]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 14, 14]       0          False
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 14, 14]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 14, 14]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 14, 14]       0          False
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 14, 14]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 14, 14]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 14, 14]       0          False
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 14, 14]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 14, 14]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 14, 14]       0          False
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [256, 14, 14]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 14, 14]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 14, 14]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 14, 14]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 14, 14]       0          False
# ______________________________________________________________________
# Conv2d               [512, 14, 14]        524,288    False
# ______________________________________________________________________
# BatchNorm2d          [512, 14, 14]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 7, 7]         1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 7, 7]         4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 7, 7]         0          False
# ______________________________________________________________________
# Conv2d               [2048, 7, 7]         2,097,152  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 7, 7]         4,096      True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 7, 7]         1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 7, 7]         4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 7, 7]         0          False
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 7, 7]         1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 7, 7]         4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 7, 7]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# Flatten              [4096]               0          False
# ______________________________________________________________________
# BatchNorm1d          [4096]               8,192      True
# ______________________________________________________________________
# Dropout              [4096]               0          False
# ______________________________________________________________________
# Linear               [512]                2,097,664  True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [3]                  1,539      True
# ______________________________________________________________________
#
# Total params: 25,616,451
# Total trainable params: 2,161,539
# Total non-trainable params: 23,454,912
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
#determining learning rate
learner.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='29' class='' max='34' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       85.29% [29/34 01:41<00:17]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.856122</td>
#       <td>#na#</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.854187</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.813886</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.880105</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.873626</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.940377</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.897314</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.928008</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.921178</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.888503</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.847245</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.785321</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.714558</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.657884</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.584513</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.495123</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.413495</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.332672</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.260653</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.177041</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.100846</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.037590</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.981604</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.944232</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.964052</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.017398</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.254063</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.764782</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.694004</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:02<00:04 3.2410]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.recorder.plot()

# %%
learner.fit_one_cycle(100, max_lr=slice(1e-2,1e-1))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.059710</td>
#       <td>2.286136</td>
#       <td>0.673077</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.967847</td>
#       <td>2.283741</td>
#       <td>0.730769</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.952967</td>
#       <td>2.324195</td>
#       <td>0.711538</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.997847</td>
#       <td>2.594884</td>
#       <td>0.653846</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.885602</td>
#       <td>2.973693</td>
#       <td>0.634615</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.821304</td>
#       <td>3.194026</td>
#       <td>0.634615</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.789986</td>
#       <td>3.034850</td>
#       <td>0.653846</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.736861</td>
#       <td>2.380881</td>
#       <td>0.692308</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.679663</td>
#       <td>1.635787</td>
#       <td>0.711538</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.632339</td>
#       <td>1.243085</td>
#       <td>0.769231</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.583108</td>
#       <td>1.018555</td>
#       <td>0.769231</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.538639</td>
#       <td>1.747070</td>
#       <td>0.788462</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.539038</td>
#       <td>2.310444</td>
#       <td>0.750000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0